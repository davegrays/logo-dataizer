# %%
#| hide
from logo_dataizer.core import *

# %% [markdown]
# # logo-dataizer
#
# > make logos look like data

# %% [markdown]
# Convert logos or icons into scatterplots of "datapoints"

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install logo_dataizer
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# initialize

# %%
from logo_dataizer.scatterizer import Scatterizer
scatterizer = Scatterizer()

# %% [markdown]
# run scatter() on any image type, just giving the filepath

# %%
scatterizer.scatter("/Users/davidg/Downloads/cloud.png")

# %% [markdown]
# By default, the output will be saved in the same location with "_scatterized" appended to the filename
#
# The following settings can be modified (defaults are in the docstring)
#
# - number of points to generate
# - amount of scatter
# - opacity
# - point size
# - size of the output image
#
# e.g.

# %%
scatterizer.scatter(
    "~/work/logo-dataizer/logo-dataizer/logo_dataizer/data/cloud.png",
    n_samples=800,
    var=0.3,
    alpha=0.4,
    width=4,
)

# %%
colors = scatterizer.scatter(
    "~/work/logo-dataizer/logo-dataizer/logo_dataizer/data/pytorch_logo.png",
    n_samples=1200,
    var=0.3,
    alpha=0.25
)
